# %%
 

System Libraries: 

sudo apt install python3 python3-pip -y 

sudo apt install libasound2-dev portaudio19-dev libportaudio2 libportaudiocpp0 -y 

sudo apt install ffmpeg libav-tools pulseaudio pulseaudio-utils -y 

sudo apt install libopencv-dev python3-opencv -y 

sudo apt install libatlas-base-dev libhdf5-dev libhdf5-serial-dev -y 

sudo apt install libssl-dev libffi-dev libjpeg-dev libtiff5-dev libjasper-dev libpng-dev -y 

sudo apt install libavcodec-dev libavformat-dev libswscale-dev libv4l-dev -y 

sudo apt install libxvidcore-dev libx264-dev -y 

sudo apt install espeak htop -y 

 

Python Environment Setup: 

sudo pip3 install virtualenv 

mkdir ~/smart_security_system 

cd ~/smart_security_system 

python3 -m venv security_env 

source security_env/bin/activate 

 

Activating virtual environment 

cd ~/smart_security_system 

source security_env/bin/activate 

 

Python Libraries  

# Web framework 

pip install flask flask-cors flask-socketio 

# Computer Vision 

pip install opencv-python opencv-contrib-python 

pip install pillow 

# Audio processing 

pip install librosa soundfile 

pip install pyaudio 

pip install scipy numpy 

# Machine Learning 

pip install tensorflow-lite-runtime 

pip install scikit-learn 

# Communication 

pip install requests websockets 

pip install python-socketio 

# Utilities 

pip install python-dotenv 

pip install logging 

pip install datetime 

pip install json 

pip install threading 

pip install queue 

# Text-to-Speech 

pip install pyttsx3 

pip install gTTS 

# GPIO (for Raspberry Pi hardware) 

pip install RPi.GPIO 

 

Flask Server & HTTPS 

 Flask Server & HTTPS 

Server runs at https://192.168.1.100:5000 

 

Enabled HTTPS using self-signed certificate (certs/cert.pem, certs/key.pem) 

 

Flask handles: 

/status – GET health check 

/upload_audio – POST audio file 

/upload_image – POST image file 

 

Network and Communication Environment Setup 

 Static IP Configuration via dhcpcd.conf 

sudo apt install dhcpcd5 

dhcpcd.conf (Y/I/N/O/D/Z) [default=N] ? N Choose N 

sudo systemctl enable dhcpcd 

sudo systemctl start dhcpcd 

sudo nano /etc/dhcpcd.conf 

Inside the dhcpcd.config, copy and paste 

interface wlan0 

static ip_address=192.168.1.100/24 

static routers=192.168.1.1 

static domain_name_servers=8.8.8.8 8.8.4.4 

Result confirmation 

hostname -I 

# Returned: 192.168.1.100 

 

 

7.  Hardware validation 

 

Requirments.txt 

flask 

flask-cors 

flask-socketio 

opencv-python 

opencv-contrib-python 

pillow 

librosa 

soundfile 

pyaudio 

scipy 

numpy 

tensorflow-lite-runtime 

scikit-learn 

requests 

websockets 

python-socketio 

python-dotenv 

pyttsx3 

gTTS 

RPi.GPIO
